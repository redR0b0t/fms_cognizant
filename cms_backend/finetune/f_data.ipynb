# %%
import pandas as pd
data=pd.read_csv('complaints.csv')
# data['complaint'].to_csv('cExamples.csv',index=False)

# %%
from instruction import instruction
input='complaint: {}'

f_data=pd.DataFrame()
f_data['instruction']=data['complaint'].apply(lambda x: instruction)
f_data['input']=data['complaint'].apply(lambda x:input.format(x))
f_data['output']=data['output']
f_data
# Out:
#                                          instruction  \
# 0  Identify the following from the complaint:\n1)...
# 1  Identify the following from the complaint:\n1)...
# 2  Identify the following from the complaint:\n1)...
# 3  Identify the following from the complaint:\n1)...
# 4  Identify the following from the complaint:\n1)...
# 5  Identify the following from the complaint:\n1)...
# 6  Identify the following from the complaint:\n1)...
#
#                                                input  \
# 0  complaint: I was not able to do payment, the w...
# 1  complaint: The hotel room was not clean, it wa...
# 2  complaint: The driver was not friendly, he did...
# 3  complaint: The driver was late by 1 hour, my f...
# 4  complaint: It took a lot of time to checkin th...
# 5  complaint: the light were not working in room ...
# 6  complaint: the application was not wokring , i...
#
#                                               output
# 0  domain:['hotel'],tags:['website'],priority:['2...
# 1  domain:['hotel'],tags:['cleaning'],priority:['...
# 2  domain:['transport'],tags:['driver'],priority:...
# 3  domain:['transport'],tags:['driver'],priority:...
# 4  domain:['hotel'],tags:['checkin','staff'],prio...
# 5  domain:['hotel'],tags:['room'],priority:['1'],...
# 6  domain:['transport'],tags:['booking','applicat...

# %%
t_data=f_data.copy()
for i in range(9000):
    t_data=pd.concat([t_data,f_data],axis=0)
t_data
# Out:
#                                           instruction  \
# 0   Identify the following from the complaint:\n1)...
# 1   Identify the following from the complaint:\n1)...
# 2   Identify the following from the complaint:\n1)...
# 3   Identify the following from the complaint:\n1)...
# 4   Identify the following from the complaint:\n1)...
# ..                                                ...
# 2   Identify the following from the complaint:\n1)...
# 3   Identify the following from the complaint:\n1)...
# 4   Identify the following from the complaint:\n1)...
# 5   Identify the following from the complaint:\n1)...
# 6   Identify the following from the complaint:\n1)...
#
#                                                 input  \
# 0   complaint: I was not able to do payment, the w...
# 1   complaint: The hotel room was not clean, it wa...
# 2   complaint: The driver was not friendly, he did...
# 3   complaint: The driver was late by 1 hour, my f...
# 4   complaint: It took a lot of time to checkin th...
# ..                                                ...
# 2   complaint: The driver was not friendly, he did...
# 3   complaint: The driver was late by 1 hour, my f...
# 4   complaint: It took a lot of time to checkin th...
# 5   complaint: the light were not working in room ...
# 6   complaint: the application was not wokring , i...
#
#                                                output
# 0   domain:['hotel'],tags:['website'],priority:['2...
# 1   domain:['hotel'],tags:['cleaning'],priority:['...
# 2   domain:['transport'],tags:['driver'],priority:...
# 3   domain:['transport'],tags:['driver'],priority:...
# 4   domain:['hotel'],tags:['checkin','staff'],prio...
# ..                                                ...
# 2   domain:['transport'],tags:['driver'],priority:...
# 3   domain:['transport'],tags:['driver'],priority:...
# 4   domain:['hotel'],tags:['checkin','staff'],prio...
# 5   domain:['hotel'],tags:['room'],priority:['1'],...
# 6   domain:['transport'],tags:['booking','applicat...
#
# [63007 rows x 3 columns]

# %%
t_data.to_csv('f_data.csv',index=False)
